# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
days=[1,2,3,5,7,8,9,12,15,17]
max_t=[27,25,25,23,33,35,32,28,27,38]
min_t=[12,13,8,9,7,10,7,9,16,14]
avg_t=[20,15,17,18,19,13,12,11,18,15]

# %%
plt.xlabel('Days in months')
plt.ylabel('Temperature in C')
plt.plot(days,max_t,label='Max')
plt.plot(days,avg_t,label='Avg')
plt.plot(days,min_t,label='Min')
plt.legend()
